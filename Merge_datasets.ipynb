# %%
import pandas as pd

# %%
columns = [
    "duration", "protocol_type", "service", "flag", "src_bytes", "dst_bytes", "land", 
    "wrong_fragment", "urgent", "hot", "num_failed_logins", "logged_in", "num_compromised", 
    "root_shell", "su_attempted", "num_root", "num_file_creations", "num_shells", 
    "num_access_files", "num_outbound_cmds", "is_host_login", "is_guest_login", "count", 
    "srv_count", "serror_rate", "srv_serror_rate", "rerror_rate", "srv_rerror_rate", 
    "same_srv_rate", "diff_srv_rate", "srv_diff_host_rate", "dst_host_count", 
    "dst_host_srv_count", "dst_host_same_srv_rate", "dst_host_diff_srv_rate", 
    "dst_host_same_src_port_rate", "dst_host_srv_diff_host_rate", "dst_host_serror_rate", 
    "dst_host_srv_serror_rate", "dst_host_rerror_rate", "dst_host_srv_rerror_rate"
]

print(columns)
# Out:
# ['duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot', 'num_failed_logins', 'logged_in', 'num_compromised', 'root_shell', 'su_attempted', 'num_root', 'num_file_creations', 'num_shells', 'num_access_files', 'num_outbound_cmds', 'is_host_login', 'is_guest_login', 'count', 'srv_count', 'serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count', 'dst_host_srv_count', 'dst_host_same_srv_rate', 'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate', 'dst_host_serror_rate', 'dst_host_srv_serror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate']

# %%
part1 = pd.read_csv("partie1.csv")
part2 = pd.read_csv("partie2.csv")
part3 = pd.read_csv("partie3.csv")

df = pd.concat([part1, part2, part3], ignore_index=True)


df.to_csv("Data", index=False)

# %%
df.head()
# Out:
#    0   tcp     http  SF   181  5450  0.1  0.2  0.3  0.4  ...  9.1  1.00.1  \
# 0  0  icmp    ecr_i  SF  1032     0    0    0    0    0  ...  255    1.00
# 1  0  icmp    ecr_i  SF  1032     0    0    0    0    0  ...  255    1.00
# 2  0   tcp  private  S0     0     0    0    0    0    0  ...    5    0.02
# 3  0   tcp     http  SF   351  8549    0    0    0    0  ...  255    1.00
# 4  0   tcp  private  S0     0     0    0    0    0    0  ...    7    0.03
#
#    0.00.6  0.11  0.00.7  0.00.8  0.00.9  0.00.10  0.00.11   normal.
# 0    0.00  1.00    0.00     0.0     0.0      0.0      0.0    smurf.
# 1    0.00  1.00    0.00     0.0     0.0      0.0      0.0    smurf.
# 2    0.08  0.00    0.00     1.0     1.0      0.0      0.0  neptune.
# 3    0.00  0.01    0.02     0.0     0.0      0.0      0.0   normal.
# 4    0.07  0.00    0.00     1.0     1.0      0.0      0.0  neptune.
#
# [5 rows x 42 columns]
